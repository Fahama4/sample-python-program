# %%
num = 14
if num%7 == 0:
  print(" number is divisible of 7")
else:
  print("number is not divisible by 7")
# Out:
#  number is divisible of 7

# %%
num = int (input("enter a number\n"))

if num%2 == 0:
    print("number is even")
else:
  print("number is odd")
# Out:
# enter a number
# 22
# number is even

# %%
num = int (input("enter a number\n"))

if num == 5:
    print("Hello")
elif num == 7:
  print("World")
else:
  print("Error")
# Out:
# enter a number
# 5
# Hello

# %%
name = "Fahama"
nationality = "pakistani "

if name == "Fahama" and "pakistani":
  print("welcome user")
else:
  print("user name is inncorrect")
# Out:
# welcome user

# %%
num = 12345
print (str(num)[::-1])
# Out:
# 54321
